# %% [markdown]
# # Name:   M.Usman Akram
# # Roll#:   20CSE_14
# # PANDAS

# %% [markdown]
# - pandas is a python library used for working with data sets.
# - it has functions for analyzing,cleaning,exploring ,and manipulating data.
# - The name "Pandas" has a reference to both "panel data" and "Python data Analysis" and was created by Mckinney in 2008.

# %% [markdown]
# ### WHY Pandas ?
# - pandas allow us to analyze big data and make conclusions based on statistical theories.
# - Pandas can clean messy data set and make them readable and relevant.
# - Relevant data is very important in data science.

# %% [markdown]
# ### Installation of Pandas:
# - If you have Python and PIP already installed on a system, then installation of Pandas is very easy.
#
# - pip install pandas

# %% [markdown]
# ### Import Pandas:
# - Once Pandas is installed, import it in your applications by adding the import keyword.
# - import pandas as pd
# - Now Pandas is imported and ready to use.
# #### Example:
# - creating  dataframe

# %%
import pandas

mydataset = {
  'Name': ["Usman", "Ahtsham", "Ahsan"],
  'Roll#': [14, 28, 26]
}

myvar = pandas.DataFrame(mydataset)

print(myvar)
# Out:
#       Name  Roll#
# 0    Usman     14
# 1  Ahtsham     28
# 2    Ahsan     26

# %% [markdown]
# #### Example:
# - Now the Pandas package can be referred to as pd instead of pandas.

# %%
import pandas as pd
my_data_set={
    "Name":["usman","Ahtsham","Ahsan"],
    "Roll#":[14,28,26]
}
my_var1=pd.DataFrame(my_data_set)
my_var1
# Out:
#       Name  Roll#
# 0    usman     14
# 1  Ahtsham     28
# 2    Ahsan     26

# %% [markdown]
# ### Checking Pandas Version
# The version string is stored under __version__ attribute.
# #### Example:

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.3.4

# %% [markdown]
# ## Pandas Series:
# - A Pandas Series is like a column in a table.
#
# - It is a one-dimensional array holding data of any type.
# #### Example:
# - Create a simple Pandas Series from a list:

# %%
import pandas as pd

a = [14,28,26,0]
myvar = pd.Series(a)
b=pd.DataFrame(myvar)


print(myvar)
# Out:
# 0    14
# 1    28
# 2    26
# 3     0
# dtype: int64

# %% [markdown]
# ### Labels:
# - If nothing else is specified, the values are labeled with their index number. First value has index 0, second value has index 1 etc.
#
# - This label can be used to access a specified value.
#
# ### Example:

# %%
import pandas as pd
a=[14,28,26]
my_var=pd.Series(a)
print(myvar[0])
print(myvar[1])
# Out:
# 14
# 28

# %% [markdown]
# ### Create Labels
# - With the index argument, you can name your own labels.
#
# #### Example:
# - Create your own labels.

# %%
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a, index = ["x", "y", "z"])

print(myvar)
print(myvar["y"])
# Out:
# x    1
# y    7
# z    2
# dtype: int64
# 7

# %% [markdown]
# - When you have created labels, you can access an item by referring to the label.

# %% [markdown]
# ### Key/Value Objects as Series:
# - You can also use a key/value object, like a dictionary, when creating a Series.
#
# #### Example
# - Create a simple Pandas Series from a dictionary

# %%
import pandas as pd
b={"usman": 14,"Ahtsham": 28,"Ahsan": 26}
m = pd.Series(b)
print(m)
# Out:
# usman      14
# Ahtsham    28
# Ahsan      26
# dtype: int64

# %% [markdown]
# - The keys of the dictionary become the labels.
#
# - To select only some of the items in the dictionary, use the index argument and specify only the items you want to include in the Series.
#
# #### Example:

# %%
import pandas as pd
b={"usman": 14,"Ahtsham": 28,"Ahsan": 26}
m = pd.Series(b,index=["usman","Ahsan"])
print(m)
# Out:
# usman    14
# Ahsan    26
# dtype: int64

# %% [markdown]
# ### DataFrames:
# - Data sets in Pandas are usually multi-dimensional tables, called DataFrames.
#
# Series is like a column, a DataFrame is the whole table.
#
# #### Example:
# Create a DataFrame from two Series:

# %%
import  pandas as pd
friends={
    "name":["usman","ahsan","Ahtsham"],
    "roll#":[14,26,28]
}
my_data=pd.DataFrame(friends)
print(my_data)
# Out:
#       name  roll#
# 0    usman     14
# 1    ahsan     26
# 2  Ahtsham     28

# %% [markdown]
# #### Example
# Create a DataFrame from two Series and use x,y,z as Label using index keyword.

# %%
import  pandas as pd
friends={
    "name":["usman","ahsan","Ahtsham"],
    "roll#":[14,26,28]
}
df=pd.DataFrame(friends,index=["x","y","z"])
print(df)
# Out:
#       name  roll#
# x    usman     14
# y    ahsan     26
# z  Ahtsham     28

# %% [markdown]
# ### Locate Row
# - As you can see from the result above, the DataFrame is like a table with rows and columns.
#
# - Pandas use the loc attribute to return one or more specified row(s)
#
# #### Example:
# - Return row 0 a:

# %%
import  pandas as pd
friends={
    "name":["usman","ahsan","Ahtsham"],
    "roll#":[14,26,28]
}
df=pd.DataFrame(friends)
print(df)
print(df.loc[0])
# Out:
#       name  roll#
# 0    usman     14
# 1    ahsan     26
# 2  Ahtsham     28
# name     usman
# roll#       14
# Name: 0, dtype: object

# %% [markdown]
# #### Example
# - Return row 0 and 1:

# %%
import pandas as pd
my_data={
    "name":["usman","Ali","zain"],
    "age":[18,19,18.5]

}
df=pd.DataFrame(my_data)

print(df)
print(df.loc[[0,1]])
# Out:
#     name   age
# 0  usman  18.0
# 1    Ali  19.0
# 2   zain  18.5
#     name   age
# 0  usman  18.0
# 1    Ali  19.0

# %% [markdown]
# ### Named Indexes:
# - With the index argument, you can name your own indexes
#
# #### Example
# - Add a list of names to give each row a name.

# %%
import pandas as pd
my_data={
    "name":["usman","Ali","zain"],
    "age":[18,19,18.5]

}
df=pd.DataFrame(my_data,index=["a","b","c"])
print(df)
# Out:
#     name   age
# a  usman  18.0
# b    Ali  19.0
# c   zain  18.5

# %% [markdown]
# ### Locate Named Indexes
# - Use the named index in the loc attribute to return the specified row(s)
#
# #### Example:
# - Return "c":

# %%
import pandas as pd
my_data={
    "name":["usman","Ali","zain"],
    "age":[18,19,18.5]

}
df=pd.DataFrame(my_data,index=["a","b","c"])
print(df)
print(df.loc["c"])
# Out:
#     name   age
# a  usman  18.0
# b    Ali  19.0
# c   zain  18.5
# name    zain
# age     18.5
# Name: c, dtype: object

# %% [markdown]
# ### Load Files Into a DataFrame
# - If your data sets are stored in a file, Pandas can load them into a DataFrame.
#
# #### Example:
# - Load a comma separated file (CSV file) into a DataFrame.

# %%
import pandas as pd

df = pd.read_csv('class.csv')

print(df.head())
# Out:
#    Gender  Location    Age Qualification    Field_Of_Study  \
# 0    Male  Pakistan  36-40       Masters  Natural Sciences
# 1    Male  Pakistan  26-30     Bachelors             CS/IT
# 2    Male  Pakistan  31-35       Masters       Enginnering
# 3  Female  Pakistan  31-35       Masters             CS/IT
# 4  Female  Pakistan  26-30       Masters       Enginnering
#
#          Purpose_For_Chilla        Job Blood_Group  Mobile_Sim   \
# 0     to boost my skill set  Unemplyed           B+      U-fone
# 1     to boost my skill set    Student           B+      U-fone
# 2  Switch my field of study   Employed           B+        Zong
# 3     to boost my skill set   Employed           O+      U-fone
# 4     to boost my skill set    Student           A-    Mobilink
#
#   Prepaid or Postpaid  ... Favorite_Programming_Language Marital_Status  \
# 0             Prepaid  ...                        Python            Yes
# 1             Prepaid  ...                        Python             No
# ...

# %% [markdown]
# ## Pandas Read CSV:
# - A simple way to store big data sets is to use CSV files (comma separated files).
#
# - CSV files contains plain text and is a well know format that can be read by everyone including Pandas.
#
# - In our examples we will be using a CSV file called 'data.csv' which is stored in pandas folder.
# - Tip: use to_string() to print the entire DataFrame.
#
# #### Example:
# - Load the CSV into a DataFrame

# %%
import pandas as pd

df = pd.read_csv('class.csv')

print(df.to_string())
# Out:
#      Gender  Location     Age  Qualification      Field_Of_Study        Purpose_For_Chilla        Job Blood_Group     Mobile_Sim  Prepaid or Postpaid             PC  Glasses When did you write your first line of code? Favorite_Programming_Language Marital_Status Vaccinated     Location.1 Working_Experience    Age   Weight    Height   Coding_Hours  Load_Sheding
# 0      Male  Pakistan   36-40        Masters    Natural Sciences     to boost my skill set  Unemplyed           B+         U-fone             Prepaid     Apna Laptop      No                                >3 years ago                        Python            Yes        Yes          Urbun                   5  38.00   77.00   179.0000          3.00             2
# ...

# %% [markdown]
# - If you have a large DataFrame with many rows, Pandas will only return the first 5 rows, and the last 5 rows
#
# #### Example
# - Print the DataFrame without the to_string() method

# %%
import pandas as pd
df=pd.read_csv("class.csv")
df
# Out:
#      Gender  Location    Age Qualification    Field_Of_Study  \
# 0      Male  Pakistan  36-40       Masters  Natural Sciences
# 1      Male  Pakistan  26-30     Bachelors             CS/IT
# 2      Male  Pakistan  31-35       Masters       Enginnering
# 3    Female  Pakistan  31-35       Masters             CS/IT
# 4    Female  Pakistan  26-30       Masters       Enginnering
# ..      ...       ...    ...           ...               ...
# 370    Male  Pakistan  26-30       Masters       Enginnering
# 371    Male  Pakistan  31-35     Bachelors       Enginnering
# 372    Male  Pakistan  21-25     Bachelors             CS/IT
# 373    Male  Pakistan  26-30       Masters       Enginnering
# 374  Female  Pakistan  31-35       Masters       Mathematics
#
#            Purpose_For_Chilla        Job Blood_Group  Mobile_Sim   \
# 0       to boost my skill set  Unemplyed           B+      U-fone
# 1       to boost my skill set    Student           B+      U-fone
# ...

# %% [markdown]
# ### max_rows
# - The number of rows returned is defined in Pandas option settings.
#
# - You can check your system's maximum rows with the pd.options.display.max_rows statement.
#
# #### Example:
# - Check the number of maximum returned rows

# %%
import pandas as pd

print(pd.options.display.max_rows)
# Out:
# 60

# %% [markdown]
# - In my system the number is 60, which means that if the DataFrame contains more than 60 rows, the print(df) statement will return only the headers and the first and last 5 rows.
#
# - You can change the maximum rows number with the same statement.

# %%
import pandas as pd
pd.options.display.max_rows=9999
df=pd.read_csv("class.csv")
df
# Out:
#      Gender  Location     Age  Qualification      Field_Of_Study  \
# 0      Male  Pakistan   36-40        Masters    Natural Sciences
# 1      Male  Pakistan   26-30      Bachelors               CS/IT
# 2      Male  Pakistan   31-35        Masters         Enginnering
# 3    Female  Pakistan   31-35        Masters               CS/IT
# 4    Female  Pakistan   26-30        Masters         Enginnering
# 5      Male  Pakistan   36-40        Masters              Others
# 6      Male  Pakistan   21-25        Masters         Enginnering
# 7      Male      West   26-30      Bachelors               CS/IT
# 8      Male  Pakistan   21-25      Bachelors               CS/IT
# 9      Male      West   21-25      Bachelors    Natural Sciences
# 10     Male      East   21-25            PhD    Natural Sciences
# 11     Male  Pakistan   26-30        Masters               CS/IT
# 12   Female      West   26-30        Masters              Others
# ...

# %% [markdown]
# ## Pandas Read JSON
# - Big data sets are often stored, or extracted as JSON.
#
# - JSON is plain text, but has the format of an object, and is well known in the world of programming, including Pandas.
# - JSON = Python Dictionary
#
# - JSON objects have the same format as Python dictionaries.
#
# #### Example:

# %%
import pandas as pd

data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %% [markdown]
# ## Analyzing DataFrames:
# ### Viewing the Data(Head Method)
# * One of the most used method for getting a quick overview of the DataFrame, is the head() method.
#
# * The head() method returns the headers and a specified number of rows, starting from the top.
#
# #### Example
# Get a quick overview by printing the first 10 rows of the DataFrame:

# %%
import pandas as pd
df=pd.read_csv("class.csv")
df.head(10)
# Out:
#    Gender  Location    Age Qualification    Field_Of_Study  \
# 0    Male  Pakistan  36-40       Masters  Natural Sciences
# 1    Male  Pakistan  26-30     Bachelors             CS/IT
# 2    Male  Pakistan  31-35       Masters       Enginnering
# 3  Female  Pakistan  31-35       Masters             CS/IT
# 4  Female  Pakistan  26-30       Masters       Enginnering
# 5    Male  Pakistan  36-40       Masters            Others
# 6    Male  Pakistan  21-25       Masters       Enginnering
# 7    Male      West  26-30     Bachelors             CS/IT
# 8    Male  Pakistan  21-25     Bachelors             CS/IT
# 9    Male      West  21-25     Bachelors  Natural Sciences
#
#          Purpose_For_Chilla        Job Blood_Group     Mobile_Sim   \
# 0     to boost my skill set  Unemplyed           B+         U-fone
# 1     to boost my skill set    Student           B+         U-fone
# 2  Switch my field of study   Employed           B+           Zong
# ...

# %% [markdown]
# #### Example
# Print the first 5 rows of the DataFrame

# %%
import pandas as pd
df=pd.read_csv("class.csv")
df.head()
# Out:
#    Gender  Location    Age Qualification    Field_Of_Study  \
# 0    Male  Pakistan  36-40       Masters  Natural Sciences
# 1    Male  Pakistan  26-30     Bachelors             CS/IT
# 2    Male  Pakistan  31-35       Masters       Enginnering
# 3  Female  Pakistan  31-35       Masters             CS/IT
# 4  Female  Pakistan  26-30       Masters       Enginnering
#
#          Purpose_For_Chilla        Job Blood_Group  Mobile_Sim   \
# 0     to boost my skill set  Unemplyed           B+      U-fone
# 1     to boost my skill set    Student           B+      U-fone
# 2  Switch my field of study   Employed           B+        Zong
# 3     to boost my skill set   Employed           O+      U-fone
# 4     to boost my skill set    Student           A-    Mobilink
#
#   Prepaid or Postpaid  ... Favorite_Programming_Language Marital_Status  \
# 0             Prepaid  ...                        Python            Yes
# 1             Prepaid  ...                        Python             No
# ...

# %% [markdown]
# ### Viewing the Data(Tail Method)
# * There is also a tail() method for viewing the last rows of the DataFrame.
#
# * The tail() method returns the headers and a specified number of rows, starting from the bottom

# %% [markdown]
# #### Example
# - Print the last 5 rows of the DataFrame

# %%
import pandas as pd
df=pd.read_csv("class.csv")
df.tail()
# Out:
#      Gender  Location    Age Qualification Field_Of_Study  \
# 370    Male  Pakistan  26-30       Masters    Enginnering
# 371    Male  Pakistan  31-35     Bachelors    Enginnering
# 372    Male  Pakistan  21-25     Bachelors          CS/IT
# 373    Male  Pakistan  26-30       Masters    Enginnering
# 374  Female  Pakistan  31-35       Masters    Mathematics
#
#            Purpose_For_Chilla        Job Blood_Group  Mobile_Sim   \
# 370     to boost my skill set   Employed           O+     Telenor
# 371     to boost my skill set   Employed           A+        Zong
# 372     to boost my skill set   Employed           O+    Mobilink
# 373     to boost my skill set   Employed           B-    Mobilink
# 374  Switch my field of study  Unemplyed           B+     Telenor
#
#     Prepaid or Postpaid  ... Favorite_Programming_Language Marital_Status  \
# 370             Prepaid  ...                             R            Yes
# ...

# %% [markdown]
# ## Info About the Data
# - The DataFrames object has a method called info(), that gives you more information about the data set.

# %%
import pandas as pd
df1=pd.read_csv("class.csv")

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375 entries, 0 to 374
# Data columns (total 23 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Gender                                       375 non-null    object
#  1   Location                                     375 non-null    object
#  2   Age                                          375 non-null    object
#  3   Qualification                                375 non-null    object
#  4   Field_Of_Study                               375 non-null    object
#  5   Purpose_For_Chilla                           375 non-null    object
#  6   Job                                          375 non-null    object
#  7   Blood_Group                                  375 non-null    object
#  8   Mobile_Sim                                   375 non-null    object
# ...

# %% [markdown]
# ### Cleaning Empty Cells:
# Empty cells can potentially give you a wrong result when you analyze data.
# ### Remove Rows:
# * One way to deal with empty cells is to remove rows that contain empty cells.
#
# * This is usually OK, since data sets can be very big, and removing a few rows will not have a big impact on the result.
#
# #### Example:
# Return a new Data Frame With No Empty Cells.

# %%
import pandas as pd
df=pd.read_csv("class.csv")
new_df=df.dropna()
print(" Data Set without removing Empty cell")
#print(df.to_string())
print("New data set wich has no empty cell")
#print(new_df.to_string())
# Out:
#  Data Set without removing Empty cell
# New data set wich has no empty cell

# %%
print(df.count())
print(new_df.count())
# Out:
# Gender                                         375
# Location                                       375
# Age                                            375
# Qualification                                  375
# Field_Of_Study                                 375
# Purpose_For_Chilla                             375
# Job                                            375
# Blood_Group                                    375
# Mobile_Sim                                     375
# Prepaid or Postpaid                            375
# PC                                             375
# Glasses                                        375
# When did you write your first line of code?    375
# Favorite_Programming_Language                  375
# Marital_Status                                 375
# Vaccinated                                     375
# Location.1                                     375
# Working_Experience                             375
# ...

# %% [markdown]
# - Note: By default, the dropna() method returns a new DataFrame, and will not change the original.
#
#
# - If you want to change the original DataFrame, use the inplace = True argument:

# %%
import pandas as pd
df=pd.read_csv("class.csv")
df.dropna(inplace=True)
print(df.to_string())
df.count()
# Out:
#      Gender  Location     Age  Qualification      Field_Of_Study        Purpose_For_Chilla        Job Blood_Group     Mobile_Sim  Prepaid or Postpaid             PC  Glasses When did you write your first line of code? Favorite_Programming_Language Marital_Status Vaccinated     Location.1 Working_Experience    Age   Weight    Height   Coding_Hours  Load_Sheding
# 0      Male  Pakistan   36-40        Masters    Natural Sciences     to boost my skill set  Unemplyed           B+         U-fone             Prepaid     Apna Laptop      No                                >3 years ago                        Python            Yes        Yes          Urbun                   5  38.00   77.00   179.0000          3.00             2
# ...

# %% [markdown]
# ## Replace Empty Values
# * Another way of dealing with empty cells is to insert a new value instead.
#
# * This way you do not have to delete entire rows just because of some empty cells.
#
# * The fillna() method allows us to replace empty cells with a value

# %% [markdown]
# #### Example:
# Replace NULL values with the number 130.

# %%
import pandas as pd
df=pd.read_csv("class.csv")
df.fillna(130000,inplace=True)
print(df.to_string())
# Out:
#      Gender  Location     Age  Qualification      Field_Of_Study        Purpose_For_Chilla        Job Blood_Group     Mobile_Sim  Prepaid or Postpaid             PC  Glasses When did you write your first line of code? Favorite_Programming_Language Marital_Status Vaccinated     Location.1 Working_Experience    Age   Weight    Height   Coding_Hours  Load_Sheding
# 0      Male  Pakistan   36-40        Masters    Natural Sciences     to boost my skill set  Unemplyed           B+         U-fone             Prepaid     Apna Laptop      No                                >3 years ago                        Python            Yes        Yes          Urbun                   5  38.00   77.00   179.0000          3.00             2
# ...

# %% [markdown]
# ### Replace Only For Specified Columns
# * The example above replaces all empty cells in the whole Data Frame.
#
# * To only replace empty values for one column, specify the column name for the DataFrame
#
# #### Example:
# Replace NULL values in the "Calories" columns with the number 130

# %%
import pandas as pd 
df=pd.read_csv("class.csv")
df["Age"].fillna(12000000,inplace=True)
print(df.to_string())
# Out:
#      Gender  Location     Age  Qualification      Field_Of_Study        Purpose_For_Chilla        Job Blood_Group     Mobile_Sim  Prepaid or Postpaid             PC  Glasses When did you write your first line of code? Favorite_Programming_Language Marital_Status Vaccinated     Location.1 Working_Experience    Age   Weight    Height   Coding_Hours  Load_Sheding
# 0      Male  Pakistan   36-40        Masters    Natural Sciences     to boost my skill set  Unemplyed           B+         U-fone             Prepaid     Apna Laptop      No                                >3 years ago                        Python            Yes        Yes          Urbun                   5  38.00   77.00   179.0000          3.00             2
# ...

# %% [markdown]
# ### Replace Using Mean, Median, or Mode
# * A common way to replace empty cells, is to calculate the mean, median or mode value of the column.
#
# * Pandas uses the mean() median() and mode() methods to calculate the respective values for a specified column
#
#
# * Mean = the average value (the sum of all values divided by number of values).
#
# #### Example:
# Calculate the MEAN, and replace any empty values with it

# %%
import pandas as pd
df=pd.read_csv("class.csv")
x=df["Coding_Hours"].mean()
print("The mean Value of Calories column is",x)
df["Age"].fillna(x,inplace=True)
print(df.to_string())
# Out:
# The mean Value of Calories column is 2.976026666666667
#      Gender  Location     Age  Qualification      Field_Of_Study        Purpose_For_Chilla        Job Blood_Group     Mobile_Sim  Prepaid or Postpaid             PC  Glasses When did you write your first line of code? Favorite_Programming_Language Marital_Status Vaccinated     Location.1 Working_Experience    Age   Weight    Height   Coding_Hours  Load_Sheding
# 0      Male  Pakistan   36-40        Masters    Natural Sciences     to boost my skill set  Unemplyed           B+         U-fone             Prepaid     Apna Laptop      No                                >3 years ago                        Python            Yes        Yes          Urbun                   5  38.00   77.00   179.0000          3.00             2
# ...

# %% [markdown]
# #### Example
# Calculate the MEDIAN, and replace any empty values with it
#
# - Median = the value in the middle, after you have sorted all values ascending.

# %%
import pandas as pd
df=pd.read_csv("class.csv")
y=df["Weight"].median()
df["Weight"].fillna(y,inplace=True)
print(df.to_string())
# Out:
#      Gender  Location     Age  Qualification      Field_Of_Study        Purpose_For_Chilla        Job Blood_Group     Mobile_Sim  Prepaid or Postpaid             PC  Glasses When did you write your first line of code? Favorite_Programming_Language Marital_Status Vaccinated     Location.1 Working_Experience    Age   Weight    Height   Coding_Hours  Load_Sheding
# 0      Male  Pakistan   36-40        Masters    Natural Sciences     to boost my skill set  Unemplyed           B+         U-fone             Prepaid     Apna Laptop      No                                >3 years ago                        Python            Yes        Yes          Urbun                   5  38.00   77.00   179.0000          3.00             2
# ...

# %% [markdown]
# #### Example
# Calculate the MODE, and replace any empty values with it
# - Mode = the value that appears most frequently

# %%
import pandas as pd
df=pd.read_csv("class.csv")
z=df["Coding_Hours"].mode()[0]
z
df["Coding_Hours"].fillna(z,inplace=True)
print(df.to_string())
# Out:
#      Gender  Location     Age  Qualification      Field_Of_Study        Purpose_For_Chilla        Job Blood_Group     Mobile_Sim  Prepaid or Postpaid             PC  Glasses When did you write your first line of code? Favorite_Programming_Language Marital_Status Vaccinated     Location.1 Working_Experience    Age   Weight    Height   Coding_Hours  Load_Sheding
# 0      Male  Pakistan   36-40        Masters    Natural Sciences     to boost my skill set  Unemplyed           B+         U-fone             Prepaid     Apna Laptop      No                                >3 years ago                        Python            Yes        Yes          Urbun                   5  38.00   77.00   179.0000          3.00             2
# ...

# %% [markdown]
# ## Cleaning Data of Wrong Format
# * Cells with data of wrong format can make it difficult, or even impossible, to analyze data.
#
# * To fix it, you have two options: remove the rows, or convert all cells in the columns into the same format.

# %% [markdown]
# ### Convert Into a Correct Format:
# In our Data Frame, we have two cells with the wrong format. Check out row 22 and 26, the 'Date' column should be a string that represents a date

# %%
import pandas as pd
df=pd.read_csv("class.csv")
print(df.to_string())
# Out:
#      Gender  Location     Age  Qualification      Field_Of_Study        Purpose_For_Chilla        Job Blood_Group     Mobile_Sim  Prepaid or Postpaid             PC  Glasses When did you write your first line of code? Favorite_Programming_Language Marital_Status Vaccinated     Location.1 Working_Experience    Age   Weight    Height   Coding_Hours  Load_Sheding
# 0      Male  Pakistan   36-40        Masters    Natural Sciences     to boost my skill set  Unemplyed           B+         U-fone             Prepaid     Apna Laptop      No                                >3 years ago                        Python            Yes        Yes          Urbun                   5  38.00   77.00   179.0000          3.00             2
# ...

# %% [markdown]
# - Let's try to convert all cells in the 'Date' column into dates.
#
# - Pandas has a to_datetime() method for this

# %%
import pandas as pd

df = pd.read_csv('class.csv')

df['Coding_Hours'] = pd.to_datetime(df['Coding_Hours'])

print(df)
# Out:
#      Gender  Location     Age  Qualification      Field_Of_Study  \
# 0      Male  Pakistan   36-40        Masters    Natural Sciences
# 1      Male  Pakistan   26-30      Bachelors               CS/IT
# 2      Male  Pakistan   31-35        Masters         Enginnering
# 3    Female  Pakistan   31-35        Masters               CS/IT
# 4    Female  Pakistan   26-30        Masters         Enginnering
# 5      Male  Pakistan   36-40        Masters              Others
# 6      Male  Pakistan   21-25        Masters         Enginnering
# 7      Male      West   26-30      Bachelors               CS/IT
# 8      Male  Pakistan   21-25      Bachelors               CS/IT
# 9      Male      West   21-25      Bachelors    Natural Sciences
# 10     Male      East   21-25            PhD    Natural Sciences
# 11     Male  Pakistan   26-30        Masters               CS/IT
# 12   Female      West   26-30        Masters              Others
# ...

# %% [markdown]
# ### Removing Rows:
# - The result from the converting in the example above gave us a NaT value, which can be handled as a NULL value, and we can remove the row by using the dropna() method.

# %%
 df.dropna(subset=['Coding_Hours'], inplace = True)
 df
# Out:
#      Gender  Location     Age  Qualification      Field_Of_Study  \
# 0      Male  Pakistan   36-40        Masters    Natural Sciences
# 1      Male  Pakistan   26-30      Bachelors               CS/IT
# 2      Male  Pakistan   31-35        Masters         Enginnering
# 3    Female  Pakistan   31-35        Masters               CS/IT
# 4    Female  Pakistan   26-30        Masters         Enginnering
# 5      Male  Pakistan   36-40        Masters              Others
# 6      Male  Pakistan   21-25        Masters         Enginnering
# 7      Male      West   26-30      Bachelors               CS/IT
# 8      Male  Pakistan   21-25      Bachelors               CS/IT
# 9      Male      West   21-25      Bachelors    Natural Sciences
# 10     Male      East   21-25            PhD    Natural Sciences
# 11     Male  Pakistan   26-30        Masters               CS/IT
# 12   Female      West   26-30        Masters              Others
# ...

# %% [markdown]
# ## Fixing Wrong Data
# ### Replacing Values
# One way to fix wrong values is to replace them with something else.

# %%
df.loc[7, 'Age'] = 45
df
# Out:
#      Gender  Location     Age  Qualification      Field_Of_Study  \
# 0      Male  Pakistan   36-40        Masters    Natural Sciences
# 1      Male  Pakistan   26-30      Bachelors               CS/IT
# 2      Male  Pakistan   31-35        Masters         Enginnering
# 3    Female  Pakistan   31-35        Masters               CS/IT
# 4    Female  Pakistan   26-30        Masters         Enginnering
# 5      Male  Pakistan   36-40        Masters              Others
# 6      Male  Pakistan   21-25        Masters         Enginnering
# 7      Male      West      45      Bachelors               CS/IT
# 8      Male  Pakistan   21-25      Bachelors               CS/IT
# 9      Male      West   21-25      Bachelors    Natural Sciences
# 10     Male      East   21-25            PhD    Natural Sciences
# 11     Male  Pakistan   26-30        Masters               CS/IT
# 12   Female      West   26-30        Masters              Others
# ...

# %% [markdown]
# For small data sets you might be able to replace the wrong data one by one, but not for big data sets.
#
# To replace wrong data for larger data sets you can create some rules, e.g. set some boundaries for legal values, and replace any values that are outside of the boundaries.

# %%
for x in df.index:
  if df.loc[x, "Weight"] > 120:
    df.loc[x, "Weight"] = 120

# %% [markdown]
# ### Removing Rows
# * Another way of handling wrong data is to remove the rows that contains wrong data.
#
# * This way you do not have to find out what to replace them with, and there is a good chance you do not need them to do your analyses.

# %%
for x in df.index:
  if df.loc[x, "Weight"] > 120:
    df.drop(x, inplace = True)

# %% [markdown]
# ## Removing Duplicates
# * Duplicate rows are rows that have been registered more than one time.
# * By taking a look at our test data set, we can assume that row 11 and 12 are duplicates.
#
# * To discover duplicates, we can use the duplicated() method.
#
# * The duplicated() method returns a Boolean values for each row
#
# #### Example
# Returns True for every row that is a duplicate, othwerwise False

# %%
print(df.duplicated().to_string())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %% [markdown]
# ### Removing Duplicates
# - To remove duplicates, use the drop_duplicates() method.
# - Remember: The (inplace = True) will make sure that the method does NOT return a new DataFrame, but it will remove all duplicates from the original DataFrame.
# #### Example
# Remove all duplicates:

# %%
df.drop_duplicates(inplace = True)

# %% [markdown]
# ## Data Correlations
# * A great aspect of the Pandas module is the corr() method.
#
# * The corr() method calculates the relationship between each column in your data set.
# * The corr() method ignores "not numeric" columns.
# #### Example
# Show the relationship between the columns

# %%
df.corr()
# Out:
#                   Age     Weight   Height   Load_Sheding
# Age           1.000000  0.288446  0.006959     -0.005033
# Weight        0.288446  1.000000 -0.052134      0.006498
# Height        0.006959 -0.052134  1.000000     -0.076098
# Load_Sheding -0.005033  0.006498 -0.076098      1.000000

# %% [markdown]
# - While it's difficult to narrow down the vast range of pandas commands to just 50, here is a list of commonly used commands in pandas for data cleaning and manipulation tasks:
#
#     1. `read_csv`: Read data from a CSV file into a DataFrame.
#     2. `head`: Display the first few rows of a DataFrame.
#     3. `tail`: Display the last few rows of a DataFrame.
#     4. `info`: Get information about the DataFrame, such as column names, data types, and missing values.
#     5. `describe`: Generate descriptive statistics of the DataFrame.
#     6. `shape`: Get the dimensions (rows and columns) of the DataFrame.
#     7. `columns`: Access the column names of the DataFrame.
#     8. `rename`: Rename columns in the DataFrame.
#     9. `drop`: Remove rows or columns from the DataFrame.
#     10. `fillna`: Fill missing values in the DataFrame with specified values or methods.
#     11. `drop_duplicates`: Remove duplicate rows from the DataFrame.
#     12. `sort_values`: Sort the DataFrame by one or more columns.
#     13. `isin`: Filter rows based on whether values are present in a given list.
#     14. `astype`: Convert the data type of a column.
#     15. `groupby`: Group the DataFrame by one or more columns.
#     16. `agg`: Apply aggregation functions to grouped data.
#     17. `merge`: Merge two DataFrames based on a common column.
#     18. `join`: Join two DataFrames based on their indexes.
#     19. `pivot_table`: Create a pivot table from the DataFrame.
#     20. `replace`: Replace values in the DataFrame with specified values.
#     21. `str.replace`: Replace values in string columns using regular expressions.
#     22. `apply`: Apply a function to each element or row/column of the DataFrame.
#     23. `map`: Map values of a column using a dictionary or a function.
#     24. `str.lower`: Convert string values to lowercase.
#     25. `str.upper`: Convert string values to uppercase.
#     26. `str.strip`: Remove leading and trailing whitespaces from string values.
#     27. `str.split`: Split string values into multiple columns based on a delimiter.
#     28. `str.contains`: Check if a string column contains a specific substring.
#     29. `str.extract`: Extract substrings from a string column using regular expressions.
#     30. `to_datetime`: Convert a column to a datetime data type.
#     31. `dt.year`: Extract year from a datetime column.
#     32. `dt.month`: Extract month from a datetime column.
#     33. `dt.day`: Extract day from a datetime column.
#     34. `dt.weekday`: Extract the weekday from a datetime column.
#     35. `cut`: Bin values into discrete intervals.
#     36. `qcut`: Bin values into quantiles.
#     37. `round`: Round numeric values to a specified number of decimals.
#     38. `astype`: Convert a column to a specific data type.
#     39. `set_index`: Set one or more columns as the DataFrame index.
#     40. `reset_index`: Reset the index of the DataFrame.
#     41. `to_csv`: Write the DataFrame to a CSV file.
#     42. `to_excel`: Write the DataFrame to an Excel file.
#     43. `to_sql`: Write the DataFrame to a SQL database.
#     44. `fillna`: Fill missing values in the DataFrame.
#     45. `dropna`: Drop rows with missing values from the DataFrame.
#     46. `duplicated`: Identify duplicate rows in the DataFrame.
#     47. `value_counts`: Count the occurrences of unique values in a column.
#     48. `nunique`: Count the number of unique values in a column.
#     49. `loc`: Access rows and columns by label.
#     50. `iloc`: Access rows and columns by integer position.
#
# - These are just a subset of the many powerful functions

# %% [markdown]
# ### Data Reading and Inspection
#     1 read_csv
#     2. read_excel
#     3. head
#     4. tail
#     5. info
#     6. describe
#     7. shape
#     8. columns
#     9. dtypes
#     10. isnull
#     11. notnull
#
#    ### Data Cleaning
#     12. drop
#     13. drop_duplicates
#     14. fillna
#     15. replace
#     16. astype
#     17. sort_values
#     18. reset_index
#     19. dropna
#     20. duplicated
#     21. dropna
#     22. drop_duplicates
#     23. str.strip
#     24. str.lower
#     25. str.upper
#     26. str.replace
#     27. str.contains
#     28. str.extract
#     29. apply
#     30. map
#     31. merge
#     32. join
#     33. pivot_table
#
#    ### Data Filtering and Selection
#     34. loc
#     35. iloc
#     36. isin
#     37. query
#
#    ### Data Aggregation and Grouping
#     38. groupby
#     39. sum
#     40. mean
#     41. median
#     42. min
#     43. max
#     44. count
#     45. nunique
#     46. agg
#     47. transform
#
#    ### Data Visualization
#     48. plot
#     49. hist
#     50. boxplot
